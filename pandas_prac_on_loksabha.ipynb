# %%
import pandas as pd

# %%
import os
#df = pd.read_csv('loksabhaseat.csv')

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_exec_path', 'get_handle_inheritable', 'get_inheritable', 'get_t
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\shash

# %%
df = pd.read_csv('c:/users/shash/hellovs/elections/loksabhaseat.csv')

# %%
df.head()
# Out:
#    seatnum               constituency                      state   total  \
# 0        1  andaman & nicobar islands  andaman & nicobar islands  207296
# 1        2                 chandigarh                 chandigarh  456568
# 2        3     dadra and nagar haveli       dadra & nagar haveli  198983
# 3        4                daman & diu                daman & diu   87469
# 4        5              chandni chowk               nct of delhi  980390
#
#    post_total  evm_total  totalcandidates
# 0         216     207080               16
# 1         361     456207               37
# 2          58     198925               12
# 3          28      87441                5
# 4        1469     978921               27

# %%
path2f = f"{os.getcwd()}/hellovs/elections/"
print(path2f)
# Out:
# C:\Users\shash/hellovs/elections/

# %%
path2fa = path2f.replace('\\','/')
path2fa
# Out:
# 'C:/Users/shash/hellovs/elections/'

# %%
df1 = pd.read_csv(f'{path2fa}loksabhaseat.csv')

# %%
df1.head()
# Out:
#    seatnum               constituency                      state   total  \
# 0        1  andaman & nicobar islands  andaman & nicobar islands  207296
# 1        2                 chandigarh                 chandigarh  456568
# 2        3     dadra and nagar haveli       dadra & nagar haveli  198983
# 3        4                daman & diu                daman & diu   87469
# 4        5              chandni chowk               nct of delhi  980390
#
#    post_total  evm_total  totalcandidates
# 0         216     207080               16
# 1         361     456207               37
# 2          58     198925               12
# 3          28      87441                5
# 4        1469     978921               27

# %%
path2fb = f"{os.getcwd()}\\hellovs\\elections\\"
path2fb
# Out:
# 'C:\\Users\\shash\\hellovs\\elections\\'

# %%
df2 = pd.read_csv(f'{path2fb}loksabhaseat.csv')

# %%
df2.head()
# Out:
#    seatnum               constituency                      state   total  \
# 0        1  andaman & nicobar islands  andaman & nicobar islands  207296
# 1        2                 chandigarh                 chandigarh  456568
# 2        3     dadra and nagar haveli       dadra & nagar haveli  198983
# 3        4                daman & diu                daman & diu   87469
# 4        5              chandni chowk               nct of delhi  980390
#
#    post_total  evm_total  totalcandidates
# 0         216     207080               16
# 1         361     456207               37
# 2          58     198925               12
# 3          28      87441                5
# 4        1469     978921               27

# %%
#to find the size and shape

# %%
df.shape
# Out:
# (543, 7)

# %%
df.size
# Out:
# 3801

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   seatnum          543 non-null    int64
#  1   constituency     543 non-null    object
#  2   state            543 non-null    object
#  3   total            543 non-null    int64
#  4   post_total       543 non-null    int64
#  5   evm_total        543 non-null    int64
#  6   totalcandidates  543 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 29.8+ KB

# %%
df.describe()
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 25%    136.500000  1.025390e+06   2046.500000  1.019656e+06        11.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 75%    407.500000  1.256621e+06   5532.000000  1.250988e+06        19.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
#column names of dataframe
df.columns
# Out:
# Index(['seatnum', 'constituency', 'state', 'total', 'post_total', 'evm_total',
#        'totalcandidates'],
#       dtype='object')

# %%
# type of dataframe columns
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
columns = df.columns

# %%
columns
# Out:
# Index(['seatnum', 'constituency', 'state', 'total', 'post_total', 'evm_total',
#        'totalcandidates'],
#       dtype='object')

# %%
print(type(columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
len(columns)
# Out:
# 7

# %%
columns[6]
# Out:
# 'totalcandidates'

# %%
# converting column names (currently in pandas index) into a list type
cols = []
for i in range(len(columns)):
    cols.append(columns[i])

# %%
cols
# Out:
# ['seatnum',
#  'constituency',
#  'state',
#  'total',
#  'post_total',
#  'evm_total',
#  'totalcandidates']

# %%
print(cols)
# Out:
# ['seatnum', 'constituency', 'state', 'total', 'post_total', 'evm_total', 'totalcandidates']

# %%
print(type(cols))
# Out:
# <class 'list'>

# %%
len(cols)
# Out:
# 7

# %%
# OR we can directly convert dataframe columns to a list
df.columns
# Out:
# Index(['seatnum', 'constituency', 'state', 'total', 'post_total', 'evm_total',
#        'totalcandidates'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['seatnum',
#  'constituency',
#  'state',
#  'total',
#  'post_total',
#  'evm_total',
#  'totalcandidates']

# %%
cols1 = list(df.columns)
print(cols1)
# Out:
# ['seatnum', 'constituency', 'state', 'total', 'post_total', 'evm_total', 'totalcandidates']

# %%
df.head(10)
# Out:
#    seatnum               constituency                      state    total  \
# 0        1  andaman & nicobar islands  andaman & nicobar islands   207296
# 1        2                 chandigarh                 chandigarh   456568
# 2        3     dadra and nagar haveli       dadra & nagar haveli   198983
# 3        4                daman & diu                daman & diu    87469
# 4        5              chandni chowk               nct of delhi   980390
# 5        6           north east delhi               nct of delhi  1461475
# 6        7                 east delhi               nct of delhi  1257821
# 7        8                  new delhi               nct of delhi   920541
# 8        9           north west delhi               nct of delhi  1402962
# 9       10                 west delhi               nct of delhi  1441601
#
#    post_total  evm_total  totalcandidates
# 0         216     207080               16
# 1         361     456207               37
# ...

# %%
df.tail()
# Out:
#      seatnum constituency      state    total  post_total  evm_total  \
# 538      539     nalgonda  telangana  1175703         953    1174750
# 539      540      bhongir  telangana  1212631        1375    1211256
# 540      541     warangal  telangana  1061645        1233    1060412
# 541      542  mahabubabad  telangana   983535         801     982734
# 542      543      khammam  telangana  1139831        1406    1138425
#
#      totalcandidates
# 538               28
# 539               14
# 540               16
# 541               15
# 542               24

# %%
#lets play with describe .. this will work on numeric columns

# %%
df.describe()
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 25%    136.500000  1.025390e+06   2046.500000  1.019656e+06        11.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 75%    407.500000  1.256621e+06   5532.000000  1.250988e+06        19.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      seatnum               constituency                      state    total  \
# 0          1  andaman & nicobar islands  andaman & nicobar islands   207296
# 1          2                 chandigarh                 chandigarh   456568
# 2          3     dadra and nagar haveli       dadra & nagar haveli   198983
# 3          4                daman & diu                daman & diu    87469
# 4          5              chandni chowk               nct of delhi   980390
# ..       ...                        ...                        ...      ...
# 538      539                   nalgonda                  telangana  1175703
# 539      540                    bhongir                  telangana  1212631
# 540      541                   warangal                  telangana  1061645
# 541      542                mahabubabad                  telangana   983535
# 542      543                    khammam                  telangana  1139831
#
# ...

# %%
df.describe()
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 25%    136.500000  1.025390e+06   2046.500000  1.019656e+06        11.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 75%    407.500000  1.256621e+06   5532.000000  1.250988e+06        19.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   seatnum          543 non-null    int64
#  1   constituency     543 non-null    object
#  2   state            543 non-null    object
#  3   total            543 non-null    int64
#  4   post_total       543 non-null    int64
#  5   evm_total        543 non-null    int64
#  6   totalcandidates  543 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 29.8+ KB

# %%
df.describe(include=[object])
# Out:
#        constituency          state
# count           543            543
# unique          540             36
# top      aurangabad  uttar pradesh
# freq              2             80

# %%
df.describe(include=[int])    
'''# by default describe gives description of int data type columns .. only to get description for 'object' 
and 'float' we use include verb'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-e8675f7adfc6> in <module>
# ----> 1 df.describe(include=[int])
#       2 '''# by default describe gives description of int data type columns .. only to get description for 'object'
#       3 and 'float' we use include verb'''
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9947                     names.append(name)
#    9948
# -> 9949         d = pd.concat([x.reindex(names, copy=False) for x in ldesc], axis=1, sort=False)
#    9950         d.columns = data.columns.copy()
#    9951         return d
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# ...

# %%
df
# Out:
#      seatnum               constituency                      state    total  \
# 0          1  andaman & nicobar islands  andaman & nicobar islands   207296
# 1          2                 chandigarh                 chandigarh   456568
# 2          3     dadra and nagar haveli       dadra & nagar haveli   198983
# 3          4                daman & diu                daman & diu    87469
# 4          5              chandni chowk               nct of delhi   980390
# ..       ...                        ...                        ...      ...
# 538      539                   nalgonda                  telangana  1175703
# 539      540                    bhongir                  telangana  1212631
# 540      541                   warangal                  telangana  1061645
# 541      542                mahabubabad                  telangana   983535
# 542      543                    khammam                  telangana  1139831
#
#      post_total  evm_total  totalcandidates
# ...

# %%
df.describe()
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 25%    136.500000  1.025390e+06   2046.500000  1.019656e+06        11.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 75%    407.500000  1.256621e+06   5532.000000  1.250988e+06        19.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
df.describe(percentiles=[.3,.5,.8])
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 30%    163.600000  1.044682e+06   2295.400000  1.040509e+06        12.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 80%    434.600000  1.283890e+06   5965.800000  1.280579e+06        21.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
df.describe(exclude=[object])
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 25%    136.500000  1.025390e+06   2046.500000  1.019656e+06        11.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 75%    407.500000  1.256621e+06   5532.000000  1.250988e+06        19.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
df.describe(exclude=[int])
# Out:
#            seatnum constituency          state         total    post_total  \
# count   543.000000          543            543  5.430000e+02    543.000000
# unique         NaN          540             36           NaN           NaN
# top            NaN   aurangabad  uttar pradesh           NaN           NaN
# freq           NaN            2             80           NaN           NaN
# mean    272.000000          NaN            NaN  1.129159e+06   4230.313076
# std     156.894869          NaN            NaN  2.275526e+05   3275.956175
# min       1.000000          NaN            NaN  0.000000e+00      0.000000
# 25%     136.500000          NaN            NaN  1.025390e+06   2046.500000
# 50%     272.000000          NaN            NaN  1.136660e+06   3396.000000
# 75%     407.500000          NaN            NaN  1.256621e+06   5532.000000
# max     543.000000          NaN            NaN  1.763757e+06  23505.000000
#
#            evm_total  totalcandidates
# ...

# %%
# transpose of the output i.e. rows to columns and columns to rows
df.describe().T
# Out:
#                  count          mean            std  min        25%  \
# seatnum          543.0  2.720000e+02     156.894869  1.0      136.5
# total            543.0  1.129159e+06  227552.615275  0.0  1025390.5
# post_total       543.0  4.230313e+03    3275.956175  0.0     2046.5
# evm_total        543.0  1.124904e+06  227443.470953  0.0  1019655.5
# totalcandidates  543.0  1.577901e+01       9.979636  0.0       11.0
#
#                        50%        75%        max
# seatnum              272.0      407.5      543.0
# total            1136660.0  1256621.0  1763757.0
# post_total          3396.0     5532.0    23505.0
# evm_total        1132803.0  1250988.0  1761240.0
# totalcandidates       14.0       19.0      186.0

# %%
df.shape
# Out:
# (543, 7)

# %%
df.shape[0]
# Out:
# 543

# %%
df.shape[1]
# Out:
# 7

# %%
type(df.shape)
# Out:
# tuple

# %%
# copy dataframe to another variable i.e. another dataframe

# %%
df_a = df.copy()

# %%
df_a.shape
# Out:
# (543, 7)

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   seatnum          543 non-null    int64
#  1   constituency     543 non-null    object
#  2   state            543 non-null    object
#  3   total            543 non-null    int64
#  4   post_total       543 non-null    int64
#  5   evm_total        543 non-null    int64
#  6   totalcandidates  543 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 29.8+ KB

# %%
df_a.describe()
# Out:
#           seatnum         total    post_total     evm_total  totalcandidates
# count  543.000000  5.430000e+02    543.000000  5.430000e+02       543.000000
# mean   272.000000  1.129159e+06   4230.313076  1.124904e+06        15.779006
# std    156.894869  2.275526e+05   3275.956175  2.274435e+05         9.979636
# min      1.000000  0.000000e+00      0.000000  0.000000e+00         0.000000
# 25%    136.500000  1.025390e+06   2046.500000  1.019656e+06        11.000000
# 50%    272.000000  1.136660e+06   3396.000000  1.132803e+06        14.000000
# 75%    407.500000  1.256621e+06   5532.000000  1.250988e+06        19.000000
# max    543.000000  1.763757e+06  23505.000000  1.761240e+06       186.000000

# %%
# to check null values in each column .. we use info() .. which gives count of non-null column values
#ALSO
# we use isnull() function

# %%
df_a.isnull()
# Out:
#      seatnum  constituency  state  total  post_total  evm_total  \
# 0      False         False  False  False       False      False
# 1      False         False  False  False       False      False
# 2      False         False  False  False       False      False
# 3      False         False  False  False       False      False
# 4      False         False  False  False       False      False
# ..       ...           ...    ...    ...         ...        ...
# 538    False         False  False  False       False      False
# 539    False         False  False  False       False      False
# 540    False         False  False  False       False      False
# 541    False         False  False  False       False      False
# 542    False         False  False  False       False      False
#
#      totalcandidates
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 538            False
# ...

# %%
df_a.isnull().sum()         # this gives count of null values present in each column  #here we dont have any :)
# Out:
# seatnum            0
# constituency       0
# state              0
# total              0
# post_total         0
# evm_total          0
# totalcandidates    0
# dtype: int64

# %%
 df_a.isnull().sum().sum()  # this will sum of sum of total null values present in dataframe
# Out:
# 0

# %%
#now we will do slicing and then extracting the data from dataframe

# %%
df_a
# Out:
#      seatnum               constituency                      state    total  \
# 0          1  andaman & nicobar islands  andaman & nicobar islands   207296
# 1          2                 chandigarh                 chandigarh   456568
# 2          3     dadra and nagar haveli       dadra & nagar haveli   198983
# 3          4                daman & diu                daman & diu    87469
# 4          5              chandni chowk               nct of delhi   980390
# ..       ...                        ...                        ...      ...
# 538      539                   nalgonda                  telangana  1175703
# 539      540                    bhongir                  telangana  1212631
# 540      541                   warangal                  telangana  1061645
# 541      542                mahabubabad                  telangana   983535
# 542      543                    khammam                  telangana  1139831
#
#      post_total  evm_total  totalcandidates
# ...

# %%
df_a['constituency']
# Out:
# 0      andaman & nicobar islands
# 1                     chandigarh
# 2         dadra and nagar haveli
# 3                    daman & diu
# 4                  chandni chowk
#                  ...
# 538                     nalgonda
# 539                      bhongir
# 540                     warangal
# 541                  mahabubabad
# 542                      khammam
# Name: constituency, Length: 543, dtype: object

# %%
df_a.constituency
# Out:
# 0      andaman & nicobar islands
# 1                     chandigarh
# 2         dadra and nagar haveli
# 3                    daman & diu
# 4                  chandni chowk
#                  ...
# 538                     nalgonda
# 539                      bhongir
# 540                     warangal
# 541                  mahabubabad
# 542                      khammam
# Name: constituency, Length: 543, dtype: object

# %%
df_a['constituency','state']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('constituency', 'state')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-9f2f01e989cd> in <module>
# ----> 1 df_a['constituency','state']
# ...

# %%
# we tried selecting 2 columns but we got this error .. to correct this the right way to fetch more than 1 column 
#     is using double square brackets

# %%
df_a[['constituency','state']]
# Out:
#                   constituency                      state
# 0    andaman & nicobar islands  andaman & nicobar islands
# 1                   chandigarh                 chandigarh
# 2       dadra and nagar haveli       dadra & nagar haveli
# 3                  daman & diu                daman & diu
# 4                chandni chowk               nct of delhi
# ..                         ...                        ...
# 538                   nalgonda                  telangana
# 539                    bhongir                  telangana
# 540                   warangal                  telangana
# 541                mahabubabad                  telangana
# 542                    khammam                  telangana
#
# [543 rows x 2 columns]

# %%
df[['constituency','state','total']]
# Out:
#                   constituency                      state    total
# 0    andaman & nicobar islands  andaman & nicobar islands   207296
# 1                   chandigarh                 chandigarh   456568
# 2       dadra and nagar haveli       dadra & nagar haveli   198983
# 3                  daman & diu                daman & diu    87469
# 4                chandni chowk               nct of delhi   980390
# ..                         ...                        ...      ...
# 538                   nalgonda                  telangana  1175703
# 539                    bhongir                  telangana  1212631
# 540                   warangal                  telangana  1061645
# 541                mahabubabad                  telangana   983535
# 542                    khammam                  telangana  1139831
#
# [543 rows x 3 columns]

# %%
# to fetch a particular row

# %%
df_a[df_a.index==0]
# Out:
#    seatnum               constituency                      state   total  \
# 0        1  andaman & nicobar islands  andaman & nicobar islands  207296
#
#    post_total  evm_total  totalcandidates
# 0         216     207080               16

# %%
df_a[df_a.index==2]
# Out:
#    seatnum            constituency                 state   total  post_total  \
# 2        3  dadra and nagar haveli  dadra & nagar haveli  198983          58
#
#    evm_total  totalcandidates
# 2     198925               12

# %%
# to select rows for a range of indexes
df_a[df_a.index.isin(range(3,6))]
# Out:
#    seatnum      constituency         state    total  post_total  evm_total  \
# 3        4       daman & diu   daman & diu    87469          28      87441
# 4        5     chandni chowk  nct of delhi   980390        1469     978921
# 5        6  north east delhi  nct of delhi  1461475        3429    1458046
#
#    totalcandidates
# 3                5
# 4               27
# 5               25

# %%
df_a[df_a.index.isin(range(1,20,3))]           # range of rows but selecting every 3rd record
# Out:
#     seatnum   constituency           state    total  post_total  evm_total  \
# 1         2     chandigarh      chandigarh   456568         361     456207
# 4         5  chandni chowk    nct of delhi   980390        1469     978921
# 7         8      new delhi    nct of delhi   920541        1485     919056
# 10       11    south delhi    nct of delhi  1214222        1711    1212511
# 13       14          aruku  andhra pradesh  1074538        7560    1066978
# 16       17  visakhapatnam  andhra pradesh  1239754        6728    1233026
# 19       20     amalapuram  andhra pradesh  1230903        8348    1222555
#
#     totalcandidates
# 1                37
# 4                27
# 7                28
# 10               28
# 13               11
# 16               15
# 19               11

# %%
df_a[df_a.total > 1000000]   # seats where total vote casted is greater than 10 lac
# Out:
#      seatnum      constituency         state    total  post_total  evm_total  \
# 5          6  north east delhi  nct of delhi  1461475        3429    1458046
# 6          7        east delhi  nct of delhi  1257821        1507    1256314
# 8          9  north west delhi  nct of delhi  1402962        1120    1401842
# 9         10        west delhi  nct of delhi  1441601        4514    1437087
# 10        11       south delhi  nct of delhi  1214222        1711    1212511
# ..       ...               ...           ...      ...         ...        ...
# 535      536          chevella     telangana  1300194        1241    1298953
# 538      539          nalgonda     telangana  1175703         953    1174750
# 539      540           bhongir     telangana  1212631        1375    1211256
# 540      541          warangal     telangana  1061645        1233    1060412
# 542      543           khammam     telangana  1139831        1406    1138425
#
#      totalcandidates
# 5                 25
# ...

# %%
df_a[df_a.total > 1000000]['constituency']      # all constituencies having total votes casted greater than 10 lacs
# Out:
# 5      north east delhi
# 6            east delhi
# 8      north west delhi
# 9            west delhi
# 10          south delhi
#              ...
# 535            chevella
# 538            nalgonda
# 539             bhongir
# 540            warangal
# 542             khammam
# Name: constituency, Length: 435, dtype: object

# %%
df_a[df_a.total > 1500000]      # constituencies having votes casted more than 15 lacs
# Out:
#      seatnum     constituency           state    total  post_total  evm_total  \
# 43        44           dhubri           assam  1685005        2389    1682616
# 46        47          gauhati           assam  1763757        2517    1761240
# 47        48        mangaldoi           assam  1506107        4452    1501655
# 164      165  bangalore rural       karnataka  1621906        1508    1620398
# 165      166  bangalore north       karnataka  1559459        3765    1555694
# 203      204           mandla  madhya pradesh  1517255        3296    1513959
# 215      216           indore  madhya pradesh  1629108        2372    1626736
# 385      386        ghaziabad   uttar pradesh  1524456        2564    1521892
# 454      455      cooch behar     west bengal  1524683        4331    1520352
# 456      457       jalpaiguri     west bengal  1500922        3211    1497711
# 532      533       malkajgiri       telangana  1563063        1663    1561400
#
#      totalcandidates
# ...

# %%
df_a[df_a.total > 1500000]['constituency'].count()      # count of constituencies having votes casted more than 15 lacs
# Out:
# 11

# %%
df_a[df_a.total > 1500000]['constituency'].sum()      # count of constituencies having votes casted more than 15 lacs
## onlu count will will .. sum function will not work
# Out:
# 'dhubrigauhatimangaldoibangalore ruralbangalore northmandlaindoreghaziabadcooch beharjalpaigurimalkajgiri'

# %%
df_a.max()            # this fetches the maximum value of each column
# Out:
# seatnum                    543
# constituency         zahirabad
# state              west bengal
# total                  1763757
# post_total               23505
# evm_total              1761240
# totalcandidates            186
# dtype: object

# %%
df_a.total.max()      # this fetches the maximum values of "total" column
# Out:
# 1763757

# %%
df_a['total'].max()
# Out:
# 1763757

# %%
df_a.total.min()
# Out:
# 0

# %%
df_a[df_a.total == 0]['constituency']
# Out:
# 340    vellore
# Name: constituency, dtype: object

# %%
df_a[df_a.total == df_a.total.max()]['constituency']          # constituency with maximum votes casted
# Out:
# 46    gauhati
# Name: constituency, dtype: object

# %%
df_a[df_a.total == df_a.total.max()][['constituency','total']]          # constituency and total values
# Out:
#    constituency    total
# 46      gauhati  1763757

# %%
df_a[df_a.total == df_a.total.max()]
# Out:
#     seatnum constituency  state    total  post_total  evm_total  \
# 46       47      gauhati  assam  1763757        2517    1761240
#
#     totalcandidates
# 46               18

# %%
df_a[df_a.total == df_a.total.max()]
# Out:
#     seatnum constituency  state    total  post_total  evm_total  \
# 46       47      gauhati  assam  1763757        2517    1761240
#
#     totalcandidates
# 46               18

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   seatnum          543 non-null    int64
#  1   constituency     543 non-null    object
#  2   state            543 non-null    object
#  3   total            543 non-null    int64
#  4   post_total       543 non-null    int64
#  5   evm_total        543 non-null    int64
#  6   totalcandidates  543 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 29.8+ KB

# %%
# to fetch unique values of a column

# %%
df_a.state.unique()
# Out:
# array(['andaman & nicobar islands', 'chandigarh', 'dadra & nagar haveli',
#        'daman & diu', 'nct of delhi', 'lakshadweep', 'puducherry',
#        'andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'goa',
#        'gujarat', 'haryana', 'himachal pradesh', 'jammu & kashmir',
#        'karnataka', 'kerala', 'madhya pradesh', 'maharashtra', 'manipur',
#        'meghalaya', 'mizoram', 'nagaland', 'odisha', 'punjab',
#        'rajasthan', 'sikkim', 'tamil nadu', 'tripura', 'uttar pradesh',
#        'west bengal', 'chhattisgarh', 'jharkhand', 'uttarakhand',
#        'telangana'], dtype=object)

# %%
type(df_a.state.unique())
# Out:
# numpy.ndarray

# %%
# to get count value of unique state values.. convert numpy array to list
len(list(df_a.state.unique()))
# Out:
# 36

# %%
# find constituency where postal votes were maximum
df_a[df_a.post_total == df_a.post_total.max()]
# Out:
#      seatnum constituency            state    total  post_total  evm_total  \
# 141      142        jammu  jammu & kashmir  1478795       23505    1455290
#
#      totalcandidates
# 141               25

# %%
df_a.sort_values('total',ascending=False).head(10)       # top ten constituencies with maximum votes using sort_values function
# Out:
#      seatnum     constituency           state    total  post_total  evm_total  \
# 46        47          gauhati           assam  1763757        2517    1761240
# 43        44           dhubri           assam  1685005        2389    1682616
# 215      216           indore  madhya pradesh  1629108        2372    1626736
# 164      165  bangalore rural       karnataka  1621906        1508    1620398
# 532      533       malkajgiri       telangana  1563063        1663    1561400
# 165      166  bangalore north       karnataka  1559459        3765    1555694
# 454      455      cooch behar     west bengal  1524683        4331    1520352
# 385      386        ghaziabad   uttar pradesh  1524456        2564    1521892
# 203      204           mandla  madhya pradesh  1517255        3296    1513959
# 47        48        mangaldoi           assam  1506107        4452    1501655
#
#      totalcandidates
# 46                18
# 43                16
# 215               21
# 164               16
# ...

# %%
df_a.sort_values('post_total',ascending=False).head(10)     
# postal votes are casted mostly done by Soldiers AND this shows the max. people serving in army from these regions
# Out:
#      seatnum constituency             state    total  post_total  evm_total  \
# 141      142        jammu   jammu & kashmir  1478795       23505    1455290
# 522      523      garhwal       uttarakhand   742784       21435     721349
# 28        29       ongole    andhra pradesh  1342368       19072    1323296
# 310      311    jhunjhunu         rajasthan  1198927       19040    1179887
# 523      524       almora       uttarakhand   694472       16548     677924
# 134      135     hamirpur  himachal pradesh   988765       16400     972365
# 132      133       kangra  himachal pradesh  1006989       15847     991142
# 311      312        sikar         rajasthan  1326969       15620    1311349
# 321      322         pali         rajasthan  1359799       14574    1345225
# 14        15   srikakulam    andhra pradesh  1157329       14318    1143011
#
#      totalcandidates
# 141               25
# 522               10
# 28                14
# 310               13
# ...

# %%
# to fetch a list of 10 highest casted total votes for constituencies of Uttar Pradesh

df_a.sort_values('total',ascending=False)[df_a.state == 'uttar pradesh'].head(10)
# Out:
# C:\Users\shash\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      seatnum         constituency          state    total  post_total  \
# 385      386            ghaziabad  uttar pradesh  1524456        2564
# 386      387  gautam buddha nagar  uttar pradesh  1392952        3297
# 419      420               jhansi  uttar pradesh  1380890        1483
# 379      380            moradabad  uttar pradesh  1282206        2537
# 407      408         mohanlalganj  uttar pradesh  1269040        5658
# 406      407                unnao  uttar pradesh  1237076        1530
# 374      375           saharanpur  uttar pradesh  1231746        2831
# 436      437          maharajganj  uttar pradesh  1226916        1230
# 383      384               meerut  uttar pradesh  1216413        4337
# 399      400             pilibhit  uttar pradesh  1186589        3699
#
# ...

# %%
# to fetch a list of 10 lowest casted total votes for constituencies of Uttar Pradesh

df_a.sort_values('total',ascending=True)[df_a.state == 'uttar pradesh'].head(10)
# Out:
# C:\Users\shash\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#      seatnum constituency          state   total  post_total  evm_total  \
# 416      417       kanpur  uttar pradesh  842994        4741     838253
# 425      426    allahabad  uttar pradesh  889056        2241     886815
# 412      413   pratapgarh  uttar pradesh  914665        4650     910015
# 444      445     salempur  uttar pradesh  921066        6707     914359
# 432      433        gonda  uttar pradesh  923816        1632     922184
# 410      411       amethi  uttar pradesh  942453        1472     940981
# 409      410   rae bareli  uttar pradesh  958556        3235     955321
# 441      442      lalganj  uttar pradesh  960568        2246     958322
# 440      441     bansgaon  uttar pradesh  969136        4072     965064
# ...

# %%
df_a[df_a.seatnum.isin(range(380,400))]           # just checking west UP stats
# Out:
#      seatnum         constituency          state    total  post_total  \
# 379      380            moradabad  uttar pradesh  1282206        2537
# 380      381               rampur  uttar pradesh  1060921         760
# 381      382              sambhal  uttar pradesh  1183469        1260
# 382      383               amroha  uttar pradesh  1169182        1874
# 383      384               meerut  uttar pradesh  1216413        4337
# 384      385              baghpat  uttar pradesh  1044894        7833
# 385      386            ghaziabad  uttar pradesh  1524456        2564
# 386      387  gautam buddha nagar  uttar pradesh  1392952        3297
# 387      388          bulandshahr  uttar pradesh  1123629        5187
# 388      389              aligarh  uttar pradesh  1163184        7154
# 389      390              hathras  uttar pradesh  1150294        6259
# 390      391              mathura  uttar pradesh  1102731        4619
# ...

# %%
# check maximum candidates from a seat

df_a.sort_values('totalcandidates',ascending=False).head(10)
# Out:
#      seatnum     constituency        state    total  post_total  evm_total  \
# 529      530        nizamabad    telangana  1062768        1146    1061622
# 143      144          belgaum    karnataka  1205229        6112    1199117
# 355      356            karur   tamil nadu  1103165        5218    1097947
# 335      336    chennai south   tamil nadu  1125857        2447    1123410
# 368      369     thoothukkudi   tamil nadu   991263        5454     985809
# 1          2       chandigarh   chandigarh   456568         361     456207
# 257      258             beed  maharashtra  1352399        3261    1349138
# 82        83          nalanda        bihar  1031286        2265    1029021
# 165      166  bangalore north    karnataka  1559459        3765    1555694
# 252      253             pune  maharashtra  1035236        1412    1033824
#
#      totalcandidates
# 529              186
# 143               58
# 355               43
# 335               41
# 368               38
# ...

# %%
# check how many candidates were from meerut and mathura

df_a[df_a.constituency == 'meerut'].totalcandidates
# Out:
# 383    12
# Name: totalcandidates, dtype: int64

# %%
df_a[df_a.constituency == 'meerut']
# Out:
#      seatnum constituency          state    total  post_total  evm_total  \
# 383      384       meerut  uttar pradesh  1216413        4337    1212076
#
#      totalcandidates
# 383               12

# %%
df_a[df_a.constituency == 'mathura']
# Out:
#      seatnum constituency          state    total  post_total  evm_total  \
# 390      391      mathura  uttar pradesh  1102731        4619    1098112
#
#      totalcandidates
# 390               14
